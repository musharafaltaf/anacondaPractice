# %% [markdown]
# # Numpy - "Numerical pyhton"
# <pre> numpy is a pyhton library 's library which is use to perform different mathematical operations on arrays
#
# Array is denoted with '[]' it is ordered (index position is fixed ), mutable (items can be modified) and homogenous (items of similar datatypes)collections of items .</pre>

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.5'

# %%
#creating 1D Array
a = np.array([1,2,3,4,5,6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
type(a) #ndarray : n-dimentional array
# Out:
# numpy.ndarray

# %%
a  = np.array([23,'cat',True,2.4])
a
# Out:
# array(['23', 'cat', 'True', '2.4'], dtype='<U32')

# %%
# tuple to array 
t = np.array((12,34,65,76)) 
t
# Out:
# array([12, 34, 65, 76])

# %%
#set to array
s = np.array({23,34,45,5,})
s
# Out:
# array({34, 45, 5, 23}, dtype=object)

# %%
#dictionary to array
d = np.array({'a':1,'b':2,'c':3})
d
# Out:
# array({'a': 1, 'b': 2, 'c': 3}, dtype=object)
