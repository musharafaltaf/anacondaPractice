# %%
a = 'HELLO FROM MUSHARAF'
print(a)
# Out:
# HELLO FROM MUSHARAF

# %%
#ELFOMSARF
a[1:18:2]
# Out:
# 'EL RMMSAA'

# %%
a = [1,2,3,4]
b = a
b.append(5)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
x = 10
y = 102
print(x is y)
# Out:
# False

# %%
a = ()
print(type(a))

# %%
print(type({}))
# Out:
# <class 'dict'>

# %%
a = [1,2,3,4,5,6]
b = a
b.remove(6)
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
student = {'name':'musharaf', 'course':'bca'}
student.update({'name':'shaka'})
print(student)
# Out:
# {'name': 'shaka', 'course': 'bca'}
